# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

# %%
df = pd.read_csv('countries.csv')
df
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
country_count_names =  df['country']
#country_count_names

pd.unique(country_count_names)
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
# data shows Top 10 countries with highest populations

df1 = pd.read_csv('countries.csv',usecols=['country','population'])

data_group = df1.groupby('country').agg({"population": "sum"}).sort_values(by=['population'], ascending=False).head(10)

data_group
# Out:
#                 population
# country
# China          11497920623
# India           8413568878
# United States   2738534790
# Indonesia       1779874000
# Brazil          1467745520
# Japan           1341105696
# Pakistan        1124200629
# Bangladesh      1089064744
# Germany          930564520
# Nigeria          884496214

# %%
china = df[df.country == 'China']
india = df[df.country == 'India']
us = df[df.country == 'United States']
indonesia = df[df.country == 'Indonesia']
Brazil = df[df.country == 'Brazil']
Nigeria = df[df.country == 'Nigeria']

# %%
#fig = plt.figure()
#ax1 = plt.subplot2grid((1,1), (0,0))

style.use('ggplot')

plt.plot(china.year,china.population/10**6,label='China', linewidth=2)
plt.plot(india.year,india.population/10**6,label='India', linewidth=2)
plt.plot(us.year,us.population/10**6,label='US', linewidth=2)
plt.plot(us.year,indonesia.population/10**6,label='Indonesia', linewidth=2)
#plt.plot(us.year,Brazil.population/10**6)
plt.plot(us.year,Nigeria.population/10**6,label='Nigeria', linewidth=2)

#fig, (ax0, ax1) = plt.subplots(nrows=2)

plt.xlabel('Year')
plt.ylabel('Population Count')
plt.title('Top 5 Country Wise Comparion ')
#plt.legend(['China','India','US','Indonesia','Nigeria'])

#ax1.spines['left'].set_visible(True)
#ax1.spines['right'].set_visible(True)
#ax1.spines['top'].set_visible(True)
#ax1.spines['top'].set_visible(True)


plt.legend()
plt.grid(True,color='k')

plt.show()
