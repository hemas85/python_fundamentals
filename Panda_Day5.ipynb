# %%
import numpy as np
import pandas as pd

# %%
cols_to_use = ['id','artist','title','medium','year','height','width','units']

# %%
df = pd.read_csv('artwork_data.csv',nrows=50,index_col='id',usecols=cols_to_use)
df
# Out:
#                 artist                                              title  \
# id
# 1035     Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1036     Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 1037     Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 1038     Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 1039    Blake, William  The Circle of the Lustful: Francesca da Rimini...
# 1040    Blake, William      Ciampolo the Barrator Tormented by the Devils
# 1041    Blake, William                        The Baffled Devils Fighting
# 1042    Blake, William  The Six-Footed Serpent Attacking Agnolo Brunel...
# 1043    Blake, William                 The Serpent Attacking Buoso Donati
# 1044    Blake, William                 The Pit of Disease: The Falsifiers
# 1045    Blake, William           Dante Striking against Bocca Degli Abati
# 1046    Blake, William                                 Job and his Family
# ...

# %%
df.to_pickle('first50.pickle')

# %%
df2=pd.read_pickle('first50.pickle')
df2
# Out:
#                 artist                                              title  \
# id
# 1035     Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1036     Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 1037     Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 1038     Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 1039    Blake, William  The Circle of the Lustful: Francesca da Rimini...
# 1040    Blake, William      Ciampolo the Barrator Tormented by the Devils
# 1041    Blake, William                        The Baffled Devils Fighting
# 1042    Blake, William  The Six-Footed Serpent Attacking Agnolo Brunel...
# 1043    Blake, William                 The Serpent Attacking Buoso Donati
# 1044    Blake, William                 The Pit of Disease: The Falsifiers
# 1045    Blake, William           Dante Striking against Bocca Degli Abati
# 1046    Blake, William                                 Job and his Family
# ...

# %%
# indexing and filtering of the pandas....

# %%
1. how many distinct artists are there in the dataset

2. how many artworks by 'Blake, William' are there in the entire dataset

# %%
df = pd.read_csv('artwork_data.csv',index_col='id')
df
# Out:
# c:\programdata\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (9,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        accession_number              artist artistRole  artistId  \
# id
# 1035             A00001       Blake, Robert     artist        38
# 1036             A00002       Blake, Robert     artist        38
# 1037             A00003       Blake, Robert     artist        38
# 1038             A00004       Blake, Robert     artist        38
# 1039             A00005      Blake, William     artist        39
# ...                 ...                 ...        ...       ...
# 122960           T13865  P-Orridge, Genesis     artist     16646
# 122961           T13866  P-Orridge, Genesis     artist     16646
# 121181           T13867        Hatoum, Mona     artist      2365
# 112306           T13868       Creed, Martin     artist      2760
# ...

# %%
how many distinct artists are there in the dataset

# %%
artits = df['artist']

# %%
len (pd.unique(artits))
# Out:
# 3336

# %%
how many artworks by 'Blake, William' are there in the entire dataset

# %%
s = df['artist'] == 'Blake, William'

print(s)
# Out:
# id
# 1035      False
# 1036      False
# 1037      False
# 1038      False
# 1039       True
#           ...
# 122960    False
# 122961    False
# 121181    False
# 112306    False
# 127035    False
# Name: artist, Length: 69201, dtype: bool

# %%
s.value_counts()
# Out:
# False    69021
# True       180
# Name: artist, dtype: int64

# %%
other way of execution :

# %%
artist_counts = df['artist'].value_counts()

# %%
artist_counts['Blake, William'] #creed, Martin
# Out:
# 180

# %%
artist_counts['Creed, Martin']
# Out:
# 13
